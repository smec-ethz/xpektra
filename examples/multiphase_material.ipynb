# %%
import pyvista

pyvista.set_jupyter_backend("client")
pyvista.start_xvfb()

# %%
import os
os.environ["JAX_CACHE_DIR"] = "/cluster/scratch/mpundir/jax-cache"
os.environ["PLOT_LIB_PATH"] = "/cluster/home/mpundir/dev"
os.environ["PYVISTA_CACHE_DIR"] = "/cluster/scratch/mpundir/"

import jax

jax.config.update("jax_compilation_cache_dir", os.environ["JAX_CACHE_DIR"])
jax.config.update("jax_persistent_cache_min_compile_time_secs", 0)
import jax.numpy as jnp

jax.config.update("jax_enable_x64", True)  # use double-precision
jax.config.update("jax_platforms", "cpu")

import numpy as np

# %% [markdown]
# In this example, we solve a lineear elasticity problem of a circular inclusion in a square matrix. The inclusion is a material with a different elastic properties than the matrix. We use the Fourier-Galerkin method to solve the problem.
#
# We import the necessary modules and set up the environment. The module `spectralsolvers` contains the operators and solvers for the Fourier-Galerkin method. We import the `fourier_galerkin` module to create the Fourier-Galerkin operator, `spatial` module to create the spatial operators, `tensor` module to create the tensor operators, and `fft` module to create the FFT and IFFT operators. We import the `conjugate_gradient_while` and `newton_krylov_solver` modules to create the solvers.
#
#
# The module `plottwist` contains the plotting functions. The module `cmcrameri` contains the colormaps.

# %%
from spectralsolvers.operators import spatial, tensor, fourier_galerkin
from spectralsolvers.fft.transform import _fft, _ifft
from spectralsolvers.solvers.linear import conjugate_gradient_while
from spectralsolvers.solvers.nonlinear import newton_krylov_solver

from functools import partial

from skimage.morphology import disk, rectangle, ellipse
import equinox as eqx
from typing import Callable

import sys  
sys.path.append(os.environ["PLOT_LIB_PATH"])
from plottwist.decorators import plot, subplots, imshow, imshow_grid, STYLE_PATH
import cmcrameri.cm as cmc
import matplotlib.pyplot as plt

# %% [markdown]
# To simplify the execution of the code, we define a `ElasticityOperator` class that contains the Fourier-Galerkin operator, the spatial operators, the tensor operators, and the FFT and IFFT operators. The `__init__` method initializes the operator and the `__call__` method computes the stresses in the real space given as
#
# $$
# \mathcal{F}^{-1} \left( \mathbb{G}:\mathcal{F}(\sigma) \right)
#
#
# $$

# %%
class ElasticityOperator(eqx.Module):
    Ghat: jnp.ndarray
    funcs: dict[str, Callable]
    elasticity_dof_shape: tuple[int, ...]

    def __init__(
        self,
        N,
        ndim,
        length,
        compute_stress,
        compute_tangent,
        gradient_operator=spatial.Operator.rotated_difference,
    ):
        self.Ghat = fourier_galerkin.compute_projection_operator_legacy(
            grid_size=(N,) * ndim, operator=gradient_operator, length=length
        )
        self.funcs = {}
        self.funcs["fft"] = jax.jit(partial(_fft, N=N, ndim=ndim))
        self.funcs["ifft"] = jax.jit(partial(_ifft, N=N, ndim=ndim))
        self.funcs["compute_tangent"] = compute_tangent
        self.funcs["compute_stress"] = compute_stress
        self.elasticity_dof_shape = (ndim, ndim) + (N,) * ndim



    def __call__(self, deps, args=None):
        deps = deps.reshape(self.elasticity_dof_shape)
        dsigma = self.funcs["compute_tangent"](deps, args)

        return jnp.real(
            self.funcs["ifft"](tensor.ddot42(self.Ghat, self.funcs["fft"](dsigma)))
        ).reshape(-1)
    
    def residual(self, deps : jnp.ndarray, args=None):
        sigma = self.funcs["compute_stress"](deps, args)
        return jnp.real(
            self.funcs["ifft"](tensor.ddot42(self.Ghat, self.funcs["fft"](sigma)))
        ).reshape(-1)

# %% [markdown]
# We define the grid size and the length of the RVE and construct the structure of the RVE.

# %%
from scipy.spatial.distance import cdist

def generate_multiphase_material_3d(size, num_phases=5, num_seeds=None, random_state=None):
    """
    Generate a 3D multiphase material using Voronoi tessellation.
    
    Parameters:
    -----------
    size : int or tuple of 3 ints
        Size of the 3D array. If int, creates a cubic array of size (size, size, size).
        If tuple, specifies (nx, ny, nz) dimensions.
    num_phases : int, default=5
        Number of different phases (materials) in the microstructure.
    num_seeds : int, optional
        Number of Voronoi seed points. If None, defaults to num_phases * 3.
    random_state : int, optional
        Random seed for reproducibility.
    
    Returns:
    --------
    material : numpy.ndarray
        3D array with values from 0 to 1, where each phase is represented by
        values in the range [i/num_phases, (i+1)/num_phases) for phase i.
    seed_points : numpy.ndarray
        Array of seed points used for Voronoi tessellation.
    """
    
    if random_state is not None:
        np.random.seed(random_state)
    
    # Handle size parameter
    if isinstance(size, int):
        nx, ny, nz = size, size, size
    else:
        nx, ny, nz = size
    
    # Default number of seeds
    if num_seeds is None:
        num_seeds = num_phases * 3
    
    # Generate random seed points in 3D space
    seed_points = np.random.rand(num_seeds, 3)
    seed_points[:, 0] *= nx
    seed_points[:, 1] *= ny
    seed_points[:, 2] *= nz
    
    # Assign each seed to a phase
    seed_phases = np.random.randint(0, num_phases, num_seeds)
    
    # Create coordinate grids
    x, y, z = np.meshgrid(np.arange(nx), np.arange(ny), np.arange(nz), indexing='ij')
    grid_points = np.column_stack([x.ravel(), y.ravel(), z.ravel()])
    
    # Calculate distances from each grid point to all seed points
    distances = cdist(grid_points, seed_points)
    
    # Find closest seed for each grid point
    closest_seeds = np.argmin(distances, axis=1)
    
    # Assign phases based on closest seed
    phase_array = seed_phases[closest_seeds].reshape(nx, ny, nz)
    
    # Convert to values between 0 and 1
    material = phase_array.astype(float) / num_phases + np.random.rand(nx, ny, nz) / (num_phases * 10)
    material = np.clip(material, 0, 1)
    
    return material, seed_points

# %%
N=63
length = 1.
ndim = 3

grid_size = (N,) * ndim
elasticity_dof_shape = (ndim, ndim) + grid_size


structure, seeds = generate_multiphase_material_3d(
        size=N, 
        num_phases=5, 
        num_seeds=15, 
        random_state=42
)

# %% [markdown]
# Next, we define the material parameters.

# %%
λ0 = structure.copy()
μ0 = structure.copy()

# %% [markdown]
# The linear elasticity strain energy is given as
# $$
# W = \frac{1}{2} \int_{\Omega}  (\lambda \text{tr}(\epsilon)^2+ \mu \text{tr}(\epsilon : \epsilon ) ) d\Omega
# $$
#
# We define a python function to compute the strain energy and then use the `jax.jacrev` function to compute the stress tensor.

# %%
@jax.jit
def strain_energy(eps, _):
    eps_sym = 0.5 * (eps + tensor.trans2(eps))
    energy = 0.5 * jnp.multiply(λ0, tensor.trace2(eps_sym) ** 2) + jnp.multiply(
        μ0, tensor.trace2(tensor.dot22(eps_sym, eps_sym))
    )
    return energy.sum()


sigma = jax.jit(jax.jacrev(strain_energy))

# %%
elasticity_op = ElasticityOperator(
    N,
    ndim,
    length,
    gradient_operator=spatial.Operator.rotated_difference,
    compute_tangent=sigma,
    compute_stress=sigma
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 elasticity_op = ElasticityOperator(
#       2     N,
#       3     ndim,
#       4     length,
#       5     gradient_operator=spatial.Operator.rotated_difference,
#       6     compute_tangent=sigma,
#       7     compute_stress=sigma
#       8 )
#
#     [... skipping hidden 2 frame]
#
# Cell In[5], line 15, in ElasticityOperator.__init__(self, N, ndim, length, compute_stress, compute_tangent, gradient_operator)
#       6 def __init__(
#       7     self,
#       8     N,
#    (...)
#      13     gradient_operator=spatial.Operator.rotated_difference,
#      14 ):
# ---> 15     self.Ghat = fourier_galerkin.compute_projection_operator_legacy(
#      16         grid_size=(N,) * ndim, operator=gradient_operator, length=length
#      17     )
#      18     self.funcs = {}
#      19     self.funcs["fft"] = jax.jit(partial(_fft, N=N, ndim=ndim))
#
#     [... skipping hidden 1 frame]
#
# File /cluster/software/stacks/2024-06/spack/opt/spack/linux-ubuntu22.04-x86_64_v3/gcc-12.2.0/python-3.11.6-ukhwpjnwzzzizek3pgr75zkbhxros5fq/lib/python3.11/site-packages/jax/_src/pjit.py:327, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     325 @api_boundary
#     326 def cache_miss(*args, **kwargs):
# --> 327   outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     328       jit_info, *args, **kwargs)
#     329   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     330   pgle_profiler = _read_pgle_profiler(jaxpr)
#
# File /cluster/software/stacks/2024-06/spack/opt/spack/linux-ubuntu22.04-x86_64_v3/gcc-12.2.0/python-3.11.6-ukhwpjnwzzzizek3pgr75zkbhxros5fq/lib/python3.11/site-packages/jax/_src/pjit.py:175, in _python_pjit_helper(jit_info, *args, **kwargs)
#     173 def _python_pjit_helper(jit_info, *args, **kwargs):
#     174   (args_flat, params, in_avals, _, out_tree, _, arg_names, _,
# --> 175    attrs_tracked) = _infer_params(jit_info, args, kwargs)
#     177   for arg in args_flat:
#     178     dispatch.check_arg(arg)
#
# File /cluster/software/stacks/2024-06/spack/opt/spack/linux-ubuntu22.04-x86_64_v3/gcc-12.2.0/python-3.11.6-ukhwpjnwzzzizek3pgr75zkbhxros5fq/lib/python3.11/site-packages/jax/_src/pjit.py:627, in _infer_params(***failed resolving arguments***)
#     620   in_type = in_avals = tuple(avals)
#     622 in_shardings_flat, in_layouts_flat = _process_in_axis_resources(
#     623     in_shardings_treedef, in_shardings_leaves,
#     624     in_layouts_treedef, in_layouts_leaves,
#     625     in_avals, in_tree, dbg, device_or_backend_set, have_kwargs)
# --> 627 jaxpr, consts, out_shardings_flat, out_layouts_flat, attrs_tracked = _pjit_jaxpr(
#     628     flat_fun, out_shardings_treedef, out_shardings_leaves,
#     629     out_layouts_treedef, out_layouts_leaves, in_type, dbg,
#     630     device_or_backend_set, HashableFunction(out_tree, closure=()),
#     631     HashableFunction(res_paths, closure=()), inline)
#     633 assert len(explicit_args) == len(in_shardings_flat) == len(in_layouts_flat)
#     635 if config.dynamic_shapes.value:
#
# File /cluster/software/stacks/2024-06/spack/opt/spack/linux-ubuntu22.04-x86_64_v3/gcc-12.2.0/python-3.11.6-ukhwpjnwzzzizek3pgr75zkbhxros5fq/lib/python3.11/site-packages/jax/_src/pjit.py:1275, in _pjit_jaxpr(fun, out_shardings_treedef, out_shardings_leaves, out_layouts_treedef, out_layouts_leaves, in_type, debug_info, device_or_backend_set, out_tree, result_paths, inline)
#    1271 def _pjit_jaxpr(fun, out_shardings_treedef, out_shardings_leaves,
#    1272                 out_layouts_treedef, out_layouts_leaves, in_type, debug_info,
#    1273                 device_or_backend_set, out_tree, result_paths, inline):
#    1274   attr_token = _attr_token(fun, in_type)
# -> 1275   jaxpr, final_consts, out_type, attrs_tracked = _create_pjit_jaxpr(
#    1276       fun, in_type, attr_token, debug_info, result_paths, IgnoreKey(inline))
#    1277   _attr_update(fun, in_type, attr_token, attrs_tracked)
#    1278   canonicalized_out_shardings_flat, out_layouts_flat = _check_and_canonicalize_out_shardings(
#    1279       out_shardings_treedef, out_shardings_leaves, out_layouts_treedef,
#    1280       out_layouts_leaves, out_tree, tuple(out_type),
#    1281       jaxpr.jaxpr.debug_info, device_or_backend_set)
#
# File /cluster/software/stacks/2024-06/spack/opt/spack/linux-ubuntu22.04-x86_64_v3/gcc-12.2.0/python-3.11.6-ukhwpjnwzzzizek3pgr75zkbhxros5fq/lib/python3.11/site-packages/jax/_src/linear_util.py:350, in cache.<locals>.memoized_fun(fun, *args)
#     348   fun.populate_stores(stores)
#     349 else:
# --> 350   ans = call(fun, *args)
#     351   if explain and config.explain_cache_misses.value:
#     352     explain(fun.f, cache is new_cache, cache, key, ans)
#
# File /cluster/software/stacks/2024-06/spack/opt/spack/linux-ubuntu22.04-x86_64_v3/gcc-12.2.0/python-3.11.6-ukhwpjnwzzzizek3pgr75zkbhxros5fq/lib/python3.11/site-packages/jax/_src/pjit.py:1189, in _create_pjit_jaxpr(***failed resolving arguments***)
#    1187     attrs_tracked = []
#    1188   else:
# -> 1189     jaxpr, global_out_avals, consts, attrs_tracked = pe.trace_to_jaxpr_dynamic(
#    1190         fun, in_type, debug_info=pe_debug)
#    1191     # assert attr_data is sentinel or attr_data matches attrs_tracked
#    1192
#    1193 # TODO(dougalm,mattjj): enable debug info with attrs_tracked
#    1194 if not config.dynamic_shapes.value and not attrs_tracked:
#
# File /cluster/software/stacks/2024-06/spack/opt/spack/linux-ubuntu22.04-x86_64_v3/gcc-12.2.0/python-3.11.6-ukhwpjnwzzzizek3pgr75zkbhxros5fq/lib/python3.11/site-packages/jax/_src/profiler.py:335, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     332 @wraps(func)
#     333 def wrapper(*args, **kwargs):
#     334   with TraceAnnotation(name, **decorator_kwargs):
# --> 335     return func(*args, **kwargs)
#     336   return wrapper
#
# File /cluster/software/stacks/2024-06/spack/opt/spack/linux-ubuntu22.04-x86_64_v3/gcc-12.2.0/python-3.11.6-ukhwpjnwzzzizek3pgr75zkbhxros5fq/lib/python3.11/site-packages/jax/_src/interpreters/partial_eval.py:2347, in trace_to_jaxpr_dynamic(fun, in_avals, debug_info, keep_inputs)
#    2345 with core.new_main(DynamicJaxprTrace, dynamic=True) as main:
#    2346   main.jaxpr_stack = ()  # type: ignore
# -> 2347   jaxpr, out_avals, consts, attrs_tracked = trace_to_subjaxpr_dynamic(
#    2348     fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    2349   del main, fun
#    2350 return jaxpr, out_avals, consts, attrs_tracked
#
# File /cluster/software/stacks/2024-06/spack/opt/spack/linux-ubuntu22.04-x86_64_v3/gcc-12.2.0/python-3.11.6-ukhwpjnwzzzizek3pgr75zkbhxros5fq/lib/python3.11/site-packages/jax/_src/interpreters/partial_eval.py:2370, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    2368 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    2369 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 2370 ans = fun.call_wrapped(*in_tracers_)
#    2371 out_tracers = map(trace.full_raise, ans)
#    2372 jaxpr, consts, attrs_tracked = frame.to_jaxpr(trace, out_tracers)
#
# File /cluster/software/stacks/2024-06/spack/opt/spack/linux-ubuntu22.04-x86_64_v3/gcc-12.2.0/python-3.11.6-ukhwpjnwzzzizek3pgr75zkbhxros5fq/lib/python3.11/site-packages/jax/_src/linear_util.py:192, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     189 gen = gen_static_args = out_store = None
#     191 try:
# --> 192   ans = self.f(*args, **dict(self.params, **kwargs))
#     193 except:
#     194   # Some transformations yield from inside context managers, so we have to
#     195   # interrupt them before reraising the exception. Otherwise they will only
#     196   # get garbage-collected at some later time, running their cleanup tasks
#     197   # only after this exception is handled, which can corrupt the global
#     198   # state.
#     199   while stack:
#
# File ~/dev/spectralsolvers/spectralsolvers/operators/fourier_galerkin.py:169, in compute_projection_operator_legacy(grid_size, length, operator)
#     167 for i, j, l, m in itertools.product(range(ndim), repeat=4):
#     168     for ind in itertools.product(*[range(n) for n in grid_size]):
# --> 169         ξ = np.empty(ndim, dtype="complex")
#     170         Dξ = np.empty(ndim, dtype="complex")
#     172         factor = 1.0
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
applied_strains = jnp.diff(jnp.linspace(0, 2e-1, num=5))

eps = jnp.zeros(elasticity_dof_shape)
deps = jnp.zeros(elasticity_dof_shape)

for inc, deps_avg in enumerate(applied_strains):
    # solving for elasticity
    deps = deps.at[0, 0].set(deps_avg)
    b = -elasticity_op(deps)
    eps = jax.lax.add(eps, deps)
    
    final_state = newton_krylov_solver(
        state=(deps, b, eps),
        A=elasticity_op,
        tol=1e-8,
        max_iter=20,
        krylov_solver=conjugate_gradient_while,
        krylov_tol=1e-8,
        krylov_max_iter=20,
        additionals=None,
    )
    eps = final_state[2]
# Out:
# Didnot converge, Residual value : 1.9867944842384207e-08
# Didnot converge, Residual value : 1.9868528951731764e-08
# Didnot converge, Residual value : 1.986852903692689e-08
# Didnot converge, Residual value : 1.9868528748305046e-08

# %%
stress00 = sigma(final_state[-1], None)[1, 1]

# %%
imshow(cmap=cmc.berlin, enable=True, return_val=False)(lambda x: x)(
    stress00.at[10, :, :].get() * (structure[10, :, :])
)

# %%
# Create the spatial reference
grid = pyvista.ImageData(origin=(0, 0, 0))

# Set the grid dimensions: shape + 1 because we want to inject our values on
#   the CELL data
grid.dimensions = np.array(stress00.shape) + 1

# Add the data values to the cell data
grid.cell_data["stress"] = stress00.flatten(order="F")  # Flatten the array
grid.cell_data["structure"] = structure.flatten(order="F")  # Flatten the array

threshed = grid.threshold(value=(0.5), scalars='structure')


pl = pyvista.Plotter(shape=(1, 1))

_ = pl.add_volume(threshed, scalars="stress", cmap=cmc.roma)

camera = pyvista.Camera()
camera.position = (120.0,120.0, 120.0)
camera.focal_point = (5.0, -10.0, 5.0)
pl.camera = camera


pl.export_html(os.environ["PYVISTA_CACHE_DIR"] + "/pv.html")
#_ = pl.screenshot( os.environ["PYVISTA_CACHE_DIR"] + "/fft_pv.png")
